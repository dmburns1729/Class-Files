# %% [markdown]
# <a href="https://colab.research.google.com/github/dmburns1729/Class-Files/blob/main/Styles_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#You can use plt.style.available to see different aesthetic styles available for your figures.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')
plt.plot([10,20,30,40,50],[5,10,15,20,25]);

# %%
plt.style.use('fivethirtyeight')
plt.plot([10,20,30,40,50],[5,10,15,20,25]);

# %%
plt.style.use('ggplot')
plt.plot([10,20,30,40,50],[5,10,15,20,25]);

# %%
plt.style.use('tableau-colorblind10')
plt.plot([10,20,30,40,50],[5,10,15,20,25]);

# %%
plt.style.use('dark_background')
plt.plot([10,20,30,40,50],[5,10,15,20,25]);
