# %% [markdown]
# <a href="https://colab.research.google.com/github/dmburns1729/Class-Files/blob/main/DataViz_Colab_Snippets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - To use these snippets, the share url for ths notebook must be added as the "Custom snippet notebook URL" field in the Settings menu.
# - Click on Tools > Settings and then find the custom snippet field. and paste in this link:
# ```https://colab.research.google.com/drive/1a4ma2HhRQi4pe2Ynlnkb5355HJ-mmM0W?usp=sharing```
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # New Section

# %% [markdown]
# - Then click on the Snippets icon on the left sidebar. (looks like `< >`)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # _DataViz: Update Colab Packages (to Match Dojo-env)

# %%
# %%time
## Update packages
# !pip install scikit-learn==1.1.3
# !pip install pandas==1.5.2
# !pip install statsmodels==0.13.2
# !pip install scipy==1.9.3
# !pip install shap==0.41.0
# !pip install lime==0.2.0.1
# !pip install matplotlib==3.6.2
# !pip install seaborn==0.12.1
## Clear Display
from IPython.display import clear_output
clear_output()

print("[i] Updating the environment took:")

# %%
## Confirm package versions
import sklearn
print(f"Sklearn version: {sklearn.__version__}")

import pandas as pd
print(f"Pandas version: {pd.__version__}")

import matplotlib as mpl
print(f"Matplotlib version: {mpl.__version__}")

import seaborn as sns
print(f"Seaborn version: {sns.__version__}")

import scipy
print(f"Scipy version: {scipy.__version__}")


import lime
try:
  pip_list = !pip list
  lime = [p for p in pip_list if 'lime' in p][0]
  print(f"Lime version: {lime.split(' ')[-1]}")
except Exception as e:
  display(e)


import shap
print(f"Shap version: {shap.__version__}")

# %% [markdown]
# # _DataViz: LP Matplotlib Style

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fav_style = ('ggplot','tableau-colorblind10')
fav_context  ={'context':'notebook', 'font_scale':1.05}
plt.style.use(fav_style)
sns.set_context(**fav_context)
plt.rcParams['savefig.transparent'] = False
plt.rcParams['savefig.bbox'] = 'tight'
